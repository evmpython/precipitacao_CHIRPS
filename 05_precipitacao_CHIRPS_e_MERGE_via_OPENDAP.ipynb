# %% [markdown]
# # **MAPA MENSAL DE PRECIPITAÇÃO**
# ---
#
#
# - CHIRPS `MENSAL`
# 1. Site: https://catalog.data.gov/dataset/chirps-version-2-0-precipitation-global-0-05a-monthly-1981-present
# 2. url dos dados: https://coastwatch.pfeg.noaa.gov/erddap/griddap/chirps20GlobalMonthlyP05
# 3. base de dados completa: https://coastwatch.pfeg.noaa.gov/erddap/index.html
# ---
#
# - MERGE `DIÁRIO`
#
# 1. Site: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/
# 2. url dos dados: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/
# 3. Informações: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/READ_ME-MERGE.pdf
#
#
# ---
#
#
# - Código realizado por: Enrique V. Mattos -- 16/04/2024 - enrique@unifei.edu.br
#
#
# ---

# %% [markdown]
# # **1° Passo:** Instalando as bibliotecas

# %%
# Instalando matplotlib, proplot e numpy
# !pip install -q matplotlib==3.4.3
# !pip install -q proplot==0.9.7
# !pip install -q numpy==1.24.3

# Instalando salem
# !pip install -q salem==0.3.9

# Instalando Xarray e suas dependências: https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# !pip install -q xarray dask netCDF4 bottleneck

# Instalando rasterio, pyproj e geopandas
# !pip install -q rasterio pyproj geopandas

# Instalando a Pygrib
# !pip install -q pygrib

# foi usado devido ao pygrib não funcionar com a versão padrão do colab
# !pip install -U numpy

# Instalando cartopy
# !pip uninstall shapely --yes
# !pip install -q shapely cartopy==0.21.1 --no-binary shapely --no-binary cartopy
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mizani 0.9.3 requires matplotlib>=3.5.0, but you have matplotlib 3.4.3 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.4.3 which is incompatible.
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.24.3)
# Collecting numpy
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mizani 0.9.3 requires matplotlib>=3.5.0, but you have matplotlib 3.4.3 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.4.3 which is incompatible.
# Successfully installed numpy-1.26.4
# Found existing installation: shapely 2.0.3
# Uninstalling shapely-2.0.3:
#   Successfully uninstalled shapely-2.0.3

# %% [markdown]
# - Chegando aqui, será necessário fazer a `Reinicialização do Ambiente de Execução`. Para isto, você deverá acessar `Ambiente de execução`, localizado na barra de ferramentas e clicar em `Reiniciar Sessão`. Como indicado na imagem abaixo.
#
# - Em seguida você deverá rodar novamente a célula anterior de instalações, de forma que as bibliotecas sejam instaladas novamente.
#
# - Isso é necessário tanto para poder usar sem problemas o `Proplot` quanto o `CartoPy` na nossa sessão do Colab. Então a partir desse ponto não teremos mais que nos preocupar com a preparação do ambiente virtual.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2° Passo:** Importando bibliotecas

# %%
import xarray as xr
import time
import proplot as pplt
import salem
import matplotlib
import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs
import numpy as np
import calendar
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import pygrib
import scipy.ndimage
import os

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **3° Passo:** Carrega shapefile

# %%
# url dos shapefiles
url = 'https://github.com/evmpython/shapefile/raw/main/'

# leitura do shapefile com a biblioteca SALEM
shp = salem.read_shapefile(f'{url}brasil/BRAZIL.shp')

# Limites do Brasil
lonmin, lonmax, latmin, latmax = -75.0, -33.0, -35.0, 7.0

# %% [markdown]
# # **PARTE 1)**:  Comparação da precipitação mensal `CHIRPS` e `MERGE`

# %% [markdown]
# ##Define o ano e mês

# %%
# define mês e ano
ano, mes = '2022', '05'

# nome do mês
nome_mes =  ['Janeiro', 'Fevereio', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Augosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

# selecina a extensão da imagem [min. lon, min. lat, max. lon, max. lat]
extent = [lonmin, latmin, lonmax, latmax]

# %% [markdown]
# ##Carrega os dados do `CHIRPS`:

# %%
# %%time
# carrega os dados do CHIRPS
chuva_chirps = xr.open_dataset('https://coastwatch.pfeg.noaa.gov/erddap/griddap/chirps20GlobalMonthlyP05')\
                 .sel(time=slice(f'{ano}-{mes}', f'{ano}-{mes}'))\
                 .sel(longitude=slice(lonmin, lonmax), latitude=slice(latmin, latmax))

# mostra os dados
chuva_chirps
# Out:
# CPU times: user 92.4 ms, sys: 14.2 ms, total: 107 ms
# Wall time: 1.24 s
# <xarray.Dataset>
# Dimensions:    (time: 1, latitude: 840, longitude: 840)
# Coordinates:
#   * time       (time) datetime64[ns] 2022-05-01
#   * latitude   (latitude) float32 -34.97 -34.92 -34.88 ... 6.875 6.925 6.975
#   * longitude  (longitude) float32 -74.98 -74.93 -74.88 ... -33.12 -33.07 -33.03
# Data variables:
#     precip     (time, latitude, longitude) float32 ...
# Attributes: (12/31)
#     acknowledgements:          The Climate Hazards Group InfraRed Precipitati...
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     creator_email:             pete@geog.ucsb.edu
#     creator_name:              Pete Peterson
#     creator_type:              person
#     ...                        ...
#     summary:                   This dataset has monthly averages of the Clima...
#     time_coverage_end:         2024-02-01T00:00:00Z
#     time_coverage_start:       1981-01-01T00:00:00Z
#     title:                     CHIRPS Version 2.0, Precipitation, Global, 0.0...
#     version:                   2.0
#     Westernmost_Easting:       -179.975

# %%
xr.open_dataset('https://coastwatch.pfeg.noaa.gov/erddap/griddap/chirps20GlobalMonthlyP05')
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 518, latitude: 2000, longitude: 7200)
# Coordinates:
#   * time       (time) datetime64[ns] 1981-01-01 1981-02-01 ... 2024-02-01
#   * latitude   (latitude) float32 -49.97 -49.92 -49.88 ... 49.87 49.92 49.97
#   * longitude  (longitude) float32 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Data variables:
#     precip     (time, latitude, longitude) float32 ...
# Attributes: (12/31)
#     acknowledgements:          The Climate Hazards Group InfraRed Precipitati...
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     creator_email:             pete@geog.ucsb.edu
#     creator_name:              Pete Peterson
#     creator_type:              person
#     ...                        ...
#     summary:                   This dataset has monthly averages of the Clima...
#     time_coverage_end:         2024-02-01T00:00:00Z
#     time_coverage_start:       1981-01-01T00:00:00Z
#     title:                     CHIRPS Version 2.0, Precipitation, Global, 0.0...
#     version:                   2.0
#     Westernmost_Easting:       -179.975

# %% [markdown]
# ##Carrega os dados do `MERGE`:

# %% [markdown]
# Baixa os dados diários do MERGE

# %%
# %%time
import calendar

# ano, mês e dia INICIAL do período
anoi = int(ano)
mesi = int(mes)
diai = 1

# ano, mês e dia FINAL do período
anof = int(ano)
mesf = int(mes)
diaf = calendar.monthrange(anof, mesf)[1]

# FTP dos dados por dia
ftp = 'http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/'

# Data desejada
date_in = datetime(anoi, mesi, diai)
date_ini = date_in.strftime('%Y%m%d')

date_en = datetime(anof, mesf, diaf)
date_end = date_en.strftime('%Y%m%d')

# Número de dias
n_days = date_en - date_in

# Download dos dados
for file in pd.date_range(date_ini, date_end, freq='d'):

    # extrai ano e mes
    ano = file.strftime('%Y')
    mes = file.strftime('%m')
    dia = file.strftime('%d')

    # nome do arquivo
    filename = f'MERGE_CPTEC_{ano}{mes}{dia}.grib2'

    # ftp + filename. Exemplo: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2023/09/MERGE_CPTEC_20230920.grib2
    ftp_filename = f'{ftp}{ano}/{mes.zfill(2)}/{filename}'

    # baixando arquivo diário de chuva
    # !wget {ftp_filename}

    print('\n---------------------')
    print('Downloading FTP File:')
    print('---------------------')
    print('Model: MERGE')
    print('File Name: ' + ftp_filename)
# Out:
# --2024-04-16 19:02:24--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220501.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 373904 (365K)
# Saving to: ‘MERGE_CPTEC_20220501.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 365.14K   611KB/s    in 0.6s
#
# 2024-04-16 19:02:25 (611 KB/s) - ‘MERGE_CPTEC_20220501.grib2’ saved [373904/373904]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220501.grib2
# --2024-04-16 19:02:25--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220502.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 418767 (409K)
# Saving to: ‘MERGE_CPTEC_20220502.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 408.95K   682KB/s    in 0.6s
#
# 2024-04-16 19:02:26 (682 KB/s) - ‘MERGE_CPTEC_20220502.grib2’ saved [418767/418767]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220502.grib2
# --2024-04-16 19:02:26--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220503.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 332967 (325K)
# Saving to: ‘MERGE_CPTEC_20220503.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 325.16K   546KB/s    in 0.6s
#
# 2024-04-16 19:02:27 (546 KB/s) - ‘MERGE_CPTEC_20220503.grib2’ saved [332967/332967]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220503.grib2
# --2024-04-16 19:02:27--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220504.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 374834 (366K)
# Saving to: ‘MERGE_CPTEC_20220504.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 366.05K   609KB/s    in 0.6s
#
# 2024-04-16 19:02:28 (609 KB/s) - ‘MERGE_CPTEC_20220504.grib2’ saved [374834/374834]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220504.grib2
# --2024-04-16 19:02:28--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220505.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 371944 (363K)
# Saving to: ‘MERGE_CPTEC_20220505.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 363.23K   608KB/s    in 0.6s
#
# 2024-04-16 19:02:29 (608 KB/s) - ‘MERGE_CPTEC_20220505.grib2’ saved [371944/371944]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220505.grib2
# --2024-04-16 19:02:29--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220506.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 364357 (356K)
# Saving to: ‘MERGE_CPTEC_20220506.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 355.82K   592KB/s    in 0.6s
#
# 2024-04-16 19:02:30 (592 KB/s) - ‘MERGE_CPTEC_20220506.grib2’ saved [364357/364357]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220506.grib2
# --2024-04-16 19:02:30--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220507.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 450840 (440K)
# Saving to: ‘MERGE_CPTEC_20220507.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 440.27K   595KB/s    in 0.7s
#
# 2024-04-16 19:02:31 (595 KB/s) - ‘MERGE_CPTEC_20220507.grib2’ saved [450840/450840]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220507.grib2
# --2024-04-16 19:02:31--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220508.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 389483 (380K)
# Saving to: ‘MERGE_CPTEC_20220508.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 380.35K   645KB/s    in 0.6s
#
# 2024-04-16 19:02:32 (645 KB/s) - ‘MERGE_CPTEC_20220508.grib2’ saved [389483/389483]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220508.grib2
# --2024-04-16 19:02:32--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220509.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 390519 (381K)
# Saving to: ‘MERGE_CPTEC_20220509.grib2’
#
# MERGE_CPTEC_2022050 100%[===================>] 381.37K   637KB/s    in 0.6s
#
# 2024-04-16 19:02:33 (637 KB/s) - ‘MERGE_CPTEC_20220509.grib2’ saved [390519/390519]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220509.grib2
# --2024-04-16 19:02:33--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220510.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 396873 (388K)
# Saving to: ‘MERGE_CPTEC_20220510.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 387.57K   649KB/s    in 0.6s
#
# 2024-04-16 19:02:34 (649 KB/s) - ‘MERGE_CPTEC_20220510.grib2’ saved [396873/396873]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220510.grib2
# --2024-04-16 19:02:34--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220511.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 399992 (391K)
# Saving to: ‘MERGE_CPTEC_20220511.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 390.62K   652KB/s    in 0.6s
#
# 2024-04-16 19:02:35 (652 KB/s) - ‘MERGE_CPTEC_20220511.grib2’ saved [399992/399992]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220511.grib2
# --2024-04-16 19:02:35--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220512.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 435380 (425K)
# Saving to: ‘MERGE_CPTEC_20220512.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 425.18K   703KB/s    in 0.6s
#
# 2024-04-16 19:02:36 (703 KB/s) - ‘MERGE_CPTEC_20220512.grib2’ saved [435380/435380]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220512.grib2
# --2024-04-16 19:02:36--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220513.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 421141 (411K)
# Saving to: ‘MERGE_CPTEC_20220513.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 411.27K   685KB/s    in 0.6s
#
# 2024-04-16 19:02:37 (685 KB/s) - ‘MERGE_CPTEC_20220513.grib2’ saved [421141/421141]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220513.grib2
# --2024-04-16 19:02:37--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220514.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 402306 (393K)
# Saving to: ‘MERGE_CPTEC_20220514.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 392.88K   657KB/s    in 0.6s
#
# 2024-04-16 19:02:38 (657 KB/s) - ‘MERGE_CPTEC_20220514.grib2’ saved [402306/402306]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220514.grib2
# --2024-04-16 19:02:38--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220515.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 406963 (397K)
# Saving to: ‘MERGE_CPTEC_20220515.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 397.42K   664KB/s    in 0.6s
#
# 2024-04-16 19:02:39 (664 KB/s) - ‘MERGE_CPTEC_20220515.grib2’ saved [406963/406963]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220515.grib2
# --2024-04-16 19:02:39--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220516.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404882 (395K)
# Saving to: ‘MERGE_CPTEC_20220516.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 395.39K   657KB/s    in 0.6s
#
# 2024-04-16 19:02:40 (657 KB/s) - ‘MERGE_CPTEC_20220516.grib2’ saved [404882/404882]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220516.grib2
# --2024-04-16 19:02:40--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220517.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427420 (417K)
# Saving to: ‘MERGE_CPTEC_20220517.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 417.40K   562KB/s    in 0.7s
#
# 2024-04-16 19:02:41 (562 KB/s) - ‘MERGE_CPTEC_20220517.grib2’ saved [427420/427420]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220517.grib2
# --2024-04-16 19:02:41--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220518.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427113 (417K)
# Saving to: ‘MERGE_CPTEC_20220518.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 417.10K   694KB/s    in 0.6s
#
# 2024-04-16 19:02:42 (694 KB/s) - ‘MERGE_CPTEC_20220518.grib2’ saved [427113/427113]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220518.grib2
# --2024-04-16 19:02:43--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220519.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 409999 (400K)
# Saving to: ‘MERGE_CPTEC_20220519.grib2’
#
# MERGE_CPTEC_2022051 100%[===================>] 400.39K   668KB/s    in 0.6s
#
# 2024-04-16 19:02:43 (668 KB/s) - ‘MERGE_CPTEC_20220519.grib2’ saved [409999/409999]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220519.grib2
# --2024-04-16 19:02:44--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220520.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384439 (375K)
# Saving to: ‘MERGE_CPTEC_20220520.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 375.43K   627KB/s    in 0.6s
#
# 2024-04-16 19:02:44 (627 KB/s) - ‘MERGE_CPTEC_20220520.grib2’ saved [384439/384439]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220520.grib2
# --2024-04-16 19:02:45--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220521.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 340969 (333K)
# Saving to: ‘MERGE_CPTEC_20220521.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 332.98K   558KB/s    in 0.6s
#
# 2024-04-16 19:02:45 (558 KB/s) - ‘MERGE_CPTEC_20220521.grib2’ saved [340969/340969]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220521.grib2
# --2024-04-16 19:02:46--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220522.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 356835 (348K)
# Saving to: ‘MERGE_CPTEC_20220522.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 348.47K   584KB/s    in 0.6s
#
# 2024-04-16 19:02:46 (584 KB/s) - ‘MERGE_CPTEC_20220522.grib2’ saved [356835/356835]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220522.grib2
# --2024-04-16 19:02:47--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220523.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381297 (372K)
# Saving to: ‘MERGE_CPTEC_20220523.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 372.36K   624KB/s    in 0.6s
#
# 2024-04-16 19:02:47 (624 KB/s) - ‘MERGE_CPTEC_20220523.grib2’ saved [381297/381297]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220523.grib2
# --2024-04-16 19:02:47--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220524.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386138 (377K)
# Saving to: ‘MERGE_CPTEC_20220524.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 377.09K   628KB/s    in 0.6s
#
# 2024-04-16 19:02:48 (628 KB/s) - ‘MERGE_CPTEC_20220524.grib2’ saved [386138/386138]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220524.grib2
# --2024-04-16 19:02:48--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220525.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 363919 (355K)
# Saving to: ‘MERGE_CPTEC_20220525.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 355.39K   595KB/s    in 0.6s
#
# 2024-04-16 19:02:49 (595 KB/s) - ‘MERGE_CPTEC_20220525.grib2’ saved [363919/363919]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220525.grib2
# --2024-04-16 19:02:49--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220526.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 368382 (360K)
# Saving to: ‘MERGE_CPTEC_20220526.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 359.75K   603KB/s    in 0.6s
#
# 2024-04-16 19:02:50 (603 KB/s) - ‘MERGE_CPTEC_20220526.grib2’ saved [368382/368382]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220526.grib2
# --2024-04-16 19:02:50--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220527.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 371497 (363K)
# Saving to: ‘MERGE_CPTEC_20220527.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 362.79K   607KB/s    in 0.6s
#
# 2024-04-16 19:02:51 (607 KB/s) - ‘MERGE_CPTEC_20220527.grib2’ saved [371497/371497]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220527.grib2
# --2024-04-16 19:02:51--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220528.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 394695 (385K)
# Saving to: ‘MERGE_CPTEC_20220528.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 385.44K   645KB/s    in 0.6s
#
# 2024-04-16 19:02:52 (645 KB/s) - ‘MERGE_CPTEC_20220528.grib2’ saved [394695/394695]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220528.grib2
# --2024-04-16 19:02:52--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220529.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334986 (327K)
# Saving to: ‘MERGE_CPTEC_20220529.grib2’
#
# MERGE_CPTEC_2022052 100%[===================>] 327.13K   548KB/s    in 0.6s
#
# 2024-04-16 19:02:53 (548 KB/s) - ‘MERGE_CPTEC_20220529.grib2’ saved [334986/334986]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220529.grib2
# --2024-04-16 19:02:53--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220530.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 412686 (403K)
# Saving to: ‘MERGE_CPTEC_20220530.grib2’
#
# MERGE_CPTEC_2022053 100%[===================>] 403.01K   672KB/s    in 0.6s
#
# 2024-04-16 19:02:54 (672 KB/s) - ‘MERGE_CPTEC_20220530.grib2’ saved [412686/412686]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220530.grib2
# --2024-04-16 19:02:54--  http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220531.grib2
# Resolving ftp.cptec.inpe.br (ftp.cptec.inpe.br)... 150.163.192.38
# Connecting to ftp.cptec.inpe.br (ftp.cptec.inpe.br)|150.163.192.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 408682 (399K)
# Saving to: ‘MERGE_CPTEC_20220531.grib2’
#
# MERGE_CPTEC_2022053 100%[===================>] 399.10K   667KB/s    in 0.6s
#
# 2024-04-16 19:02:56 (667 KB/s) - ‘MERGE_CPTEC_20220531.grib2’ saved [408682/408682]
#
#
# ---------------------
# Downloading FTP File:
# ---------------------
# Model: MERGE
# File Name: http://ftp.cptec.inpe.br/modelos/tempo/MERGE/GPM/DAILY/2022/05/MERGE_CPTEC_20220531.grib2
# CPU times: user 706 ms, sys: 119 ms, total: 825 ms
# Wall time: 32 s

# %% [markdown]
# Soma a chuva do MERGE

# %%
# %%time
# Loop nos arquivos diários. date_ini='20231201' e date_end='20231231'
for data in pd.date_range(date_ini, date_end, freq='d'):

    # Extrai no formato '2021-10-17 00:00:00' para '20211017'
    ano_mes_dia = data.strftime('%Y%m%d')

    # Monta o nome do arquivo 'MERGE_CPTEC_20211001.grib2'
    file_name = f'MERGE_CPTEC_{str(ano_mes_dia)}.grib2'

    # Monta o caminho e nome do arquivo '/content/input/MERGE_CPTEC_20211017.grib2'
    grib = f'/content/{file_name}'

    # Se o arquivo existe
    if (os.path.exists(grib)):

        # imprimindo na tela o arquivo atual
        print('Processando arquivo:', grib)

        # Lendo o arquivo
        grib = pygrib.open(grib)

        # Lendo o campo do modelo
        grb = grib.select(name='Precipitation')[0]

        # Extrai os dados para uma área específica
        precip, lats, lons = grb.data(lat1=extent[1],lat2=extent[3],lon1=extent[0]+360,lon2=extent[2]+360)

        # Converter de 'kg m**-2 s**-1' para 'mm/h'
        #precip = precip * 60 * 60

        # Suaviza os contornos
        #precip = scipy.ndimage.zoom(precip, 3)
        #lons = scipy.ndimage.zoom(lons, 3)
        #lats = scipy.ndimage.zoom(lats, 3)

        # Se é o primeiro ciclo, cria um array que guardará os valores médios
        if (ano_mes_dia == date_ini):
            precip_sum = np.zeros( (precip.shape[0], precip.shape[1]) )
            precip_max = np.full((precip.shape[0], precip.shape[1]), -9999)
            precip_min = np.full((precip.shape[0], precip.shape[1]),  9999)

        # Soma os valores
        precip_sum = precip_sum + precip

        # Extrai o valor máximo
        precip_max = np.maximum(precip, precip_max)

        # Extrai o valor mínimo
        precip_min = np.minimum(precip, precip_min)

# Calcula o valor médio
precip_med = precip_sum / n_days.days

# colocar chuva abaixo de 1 mm/h como "Not a Number"
precip_min[precip_min < 1] = np.nan
precip_max[precip_max < 1] = np.nan
precip_med[precip_med < 1] = np.nan
precip_sum[precip_sum < 1] = np.nan
# Out:
# Processando arquivo: /content/MERGE_CPTEC_20220501.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220502.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220503.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220504.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220505.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220506.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220507.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220508.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220509.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220510.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220511.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220512.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220513.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220514.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220515.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220516.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220517.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220518.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220519.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220520.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220521.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220522.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220523.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220524.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220525.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220526.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220527.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220528.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220529.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220530.grib2
# Processando arquivo: /content/MERGE_CPTEC_20220531.grib2
# CPU times: user 10.4 s, sys: 444 ms, total: 10.8 s
# Wall time: 10.9 s

# %% [markdown]
# Transforma a matriz para DataSet

# %%
# quantidade de colunas e linhas da matriz
nx, ny = precip_sum.shape[1], precip_sum.shape[0]

# define a matriz de latitude e longitude
lats2 = lats[:,0]
lons2 = ((lons[0,:] + 180) % 360) - 180 # transforma as longitudes de 0/360 para -180/180

# gerando dataset em formato netcdf
data_vars = {'rain':(('lat', 'lon'), precip_sum, {'units': 'mm/mês', 'long_name':'precipitação mensal do MERGE'})}
coords = {'lat': lats2, 'lon': lons2}
chuva_merge = xr.Dataset(data_vars=data_vars, coords=coords)

# salva arquivo NETCDF
chuva_merge.to_netcdf(f'/content/MERGE_CPTEC_{ano}{mes}.nc')

# %% [markdown]
# ##Plota figura

# %%
# mostra os dados do CHIRPS
chuva_chirps
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, latitude: 840, longitude: 840)
# Coordinates:
#   * time       (time) datetime64[ns] 2022-05-01
#   * latitude   (latitude) float32 -34.97 -34.92 -34.88 ... 6.875 6.925 6.975
#   * longitude  (longitude) float32 -74.98 -74.93 -74.88 ... -33.12 -33.07 -33.03
# Data variables:
#     precip     (time, latitude, longitude) float32 ...
# Attributes: (12/31)
#     acknowledgements:          The Climate Hazards Group InfraRed Precipitati...
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     creator_email:             pete@geog.ucsb.edu
#     creator_name:              Pete Peterson
#     creator_type:              person
#     ...                        ...
#     summary:                   This dataset has monthly averages of the Clima...
#     time_coverage_end:         2024-02-01T00:00:00Z
#     time_coverage_start:       1981-01-01T00:00:00Z
#     title:                     CHIRPS Version 2.0, Precipitation, Global, 0.0...
#     version:                   2.0
#     Westernmost_Easting:       -179.975

# %%
# mostra os dados do MERGE
chuva_merge
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 420, lon: 420)
# Coordinates:
#   * lat      (lat) float64 -34.95 -34.85 -34.75 -34.65 ... 6.65 6.75 6.85 6.95
#   * lon      (lon) float64 -74.95 -74.85 -74.75 -74.65 ... -33.25 -33.15 -33.05
# Data variables:
#     rain     (lat, lon) float64 21.88 21.75 20.25 19.88 ... 47.5 45.5 45.38

# %%
# %%time
#========================================================================================================================#
#                                           PLOTA FIGURA
#========================================================================================================================#
# cria a moldura da figura
fig, ax = pplt.subplots(axwidth=6, ncols=2, nrows=1, tight=True, proj='pcarree')

# define formato da figura
ax.format(coast=False, borders=False, innerborders=False,
          labels=False, latlines=5, lonlines=10,
          latlim=(latmin, latmax), lonlim=(lonmin, lonmax),
          small='20px', large='25px',
          linewidth=0, grid=False,
          suptitle=f'{nome_mes[int(mes)-1]} de {ano}')

#--------------------------------------------------------------#
#                            FIG-1
#--------------------------------------------------------------#
# plota mapa
map1 = ax[0].contourf(chuva_chirps['longitude'],
                      chuva_chirps['latitude'],
                      chuva_chirps['precip'][0,:,:].salem.roi(shape=shp),
                      cmap='oslo_r',
                      vmin=50, vmax=400,
                      levels=pplt.arange(50, 400, 50),
                      extend='both',
                      colorbar='best',
                      colorbar_kw={'label': 'mm/mês',
                                   'length': 18,
                                   'frameon': False,
                                   'ticklabelsize': 10,
                                   'labelsize': 10,
                                   'width': 2,
                                   'ticks': 50})

# título da figura
ax[0].format(title=f'CHIRPS',
             titleloc='c',
             titleweight='bold',
             titlecolor='grey')

# plota contorno dos Estados
estados_brasil = salem.read_shapefile('https://github.com/evmpython/shapefile/raw/main/estados_do_brasil/BR_UF_2019.shp')
estados_brasil.plot(edgecolor='gray', facecolor='none', linewidth=0.5, alpha=1, ax=ax[0])

# plota contorno do Brasil
contorno_brasil = salem.read_shapefile('https://github.com/evmpython/shapefile/raw/main/brasil/BRAZIL.shp')
contorno_brasil.plot(edgecolor='black', facecolor='none', linewidth=1.0, alpha=1, ax=ax[0])

# informação na figura
ax[0].annotate('Prof. Enrique Mattos/UNIFEI\ngithub.com/evmpython', xy=(lonmin,latmin), fontsize=7, color='black')

#--------------------------------------------------------------#
#                            FIG-2
#--------------------------------------------------------------#
ax[1].contourf(chuva_merge['lon'],
               chuva_merge['lat'],
               chuva_merge['rain'][:,:].salem.roi(shape=shp),
               cmap='oslo_r',
               vmin=50, vmax=400,
               levels=pplt.arange(50, 400, 50),
               extend='both',
               colorbar='best',
               colorbar_kw={'label': 'mm/mês',
                            'length': 18,
                            'frameon': False,
                            'ticklabelsize': 10,
                            'labelsize': 10,
                            'width': 2,
                            'ticks': 50})

# título da figura
ax[1].format(title=f'MERGE',
             titleloc='c',
             titleweight='bold',
             titlecolor='grey')

# plota contorno dos Estados
estados_brasil = salem.read_shapefile('https://github.com/evmpython/shapefile/raw/main/estados_do_brasil/BR_UF_2019.shp')
estados_brasil.plot(edgecolor='gray', facecolor='none', linewidth=0.5, alpha=1, ax=ax[1])

# plota contorno do Brasil
contorno_brasil = salem.read_shapefile('https://github.com/evmpython/shapefile/raw/main/brasil/BRAZIL.shp')
contorno_brasil.plot(edgecolor='black', facecolor='none', linewidth=1.0, alpha=1, ax=ax[1])

# salva figura
fig.save(f'Fig_8_chirps_merge_mensal_{ano}{mes}.jpg', dpi=300)
# Out:
# CPU times: user 15.4 s, sys: 2.23 s, total: 17.7 s
# Wall time: 21.5 s
# Figure(nrows=1, ncols=2, refwidth=6.0)
